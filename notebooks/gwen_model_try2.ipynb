# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
import pandas as pd
import numpy as np
from tensorflow.keras import Sequential, Input, layers
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import LabelEncoder
from PIL import Image

# %% [markdown]
# # Import the dataset

# %%
file_path="data_sampling1000_topstyles.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#                 artist               style       movement  \
# 0      Nicolae Vermont             Realism        Realism
# 1     William Hamilton       Neoclassicism  Neoclassicism
# 2  John Singer Sargent             Realism        Realism
# 3         Lucian Freud       Expressionism  Expressionism
# 4     Ferdinand Hodler  Post-Impressionism      Symbolism
#
#                                                 tags  \
# 0                                      ['Gentleman']
# 1                                           ['Lady']
# 2                       ['female-portraits', 'Lady']
# 3                 ['male-nude', 'Mythology', 'Male']
# 4  ['lakes-and-ponds', 'Alps', 'mountains', 'Lake...
#
#                                                  url  \
# 0  https://www.wikiart.org/en/nicolae-vermont/por...
# 1  https://www.wikiart.org/en/william-hamilton/ol...
# 2  https://www.wikiart.org/en/john-singer-sargent...
# 3  https://www.wikiart.org/en/lucian-freud/david-...
# 4  https://www.wikiart.org/en/ferdinand-hodler/la...
#
#                                                  img  \
# 0  https://uploads0.wikiart.org/images/nicolae-ve...
# 1  https://uploads1.wikiart.org/images/william-ha...
# 2  https://uploads4.wikiart.org/images/john-singe...
# 3  https://uploads2.wikiart.org/images/lucian-fre...
# 4  https://uploads0.wikiart.org/images/ferdinand-...
#
#                                   file_name              genre_list Artwork  \
# 0          75532-portrait-of-a-man-1918.jpg            ['portrait']     NaN
# 1          31044-olivia-s-proposal-1796.jpg        ['illustration']     NaN
# 2          73103-the-misses-hunter-1902.jpg            ['portrait']     NaN
# 3             137838-david-and-eli-2004.jpg  ['nude painting (nu)']     NaN
# 4  81578-lake-geneva-from-chexbres-1904.jpg           ['landscape']     NaN
#
#   Date
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
list_styles = df['style'].unique().tolist()
list_styles
# Out:
# ['Realism',
#  'Neoclassicism',
#  'Expressionism',
#  'Post-Impressionism',
#  'Abstract Expressionism',
#  'Symbolism',
#  'Romanticism',
#  'Impressionism',
#  'Surrealism',
#  'Cubism']

# %%
nb_styles = len(list_styles)
nb_styles
# Out:
# 10

# %%
list_images= df['file_name'].unique().tolist()
list_images
# Out:
# ['75532-portrait-of-a-man-1918.jpg',
#  '31044-olivia-s-proposal-1796.jpg',
#  '73103-the-misses-hunter-1902.jpg',
#  '137838-david-and-eli-2004.jpg',
#  '81578-lake-geneva-from-chexbres-1904.jpg',
#  '213335-tapestry-1962.jpg',
#  '70773-woman-with-dagger.jpg',
#  '80123-in-the-section-1879.jpg',
#  '44910-naples.jpg',
#  '104115-san-gabriel-canyon.jpg',
#  '65781-nikita-pustosviat-dispute-on-the-confession-of-faith-1881.jpg',
#  '182428-the-lady-rose-1934.jpg',
#  '51287-blondel-s-quest.jpg',
#  '164195-number-180-2007.jpg',
#  '44207-coastal-twilight.jpg',
#  '101651-idle-hours.jpg',
#  '43210-after-the-shipwreck.jpg',
#  '99076-hugo-m-hlig-pappelw-ldchen-1906.jpg',
#  '132547-not_detected_235896.jpg',
#  '38340-a-country-kitchen-1811.jpg',
#  '51180-whitby-abbey-1872.jpg',
#  '31757-grande-arm-e-7th-regiment-of-cuirassiers-officers-full-dress.jpg',
#  '44102-william-ewart-lockhart-artist-1891.jpg',
#  '118463-at-grand-lemps-also-known-as-the-park.jpg',
#  '94742-paul-cezanne-1880.jpg',
#  '156013-portrait-of-trotsky-1926.jpg',
#  '246432-the-man-with-cat-and-dragonfly.jpg',
#  '43243-sea-2.jpg',
#  '133535-trees-mirrored-in-a-pond-1907.jpg',
#  '121784-konstantin-gorbatov-scarborough.jpg',
#  '96543-a-kiss-for-baby-anne.jpg',
#  '137741-annabel-sleeping-1988.jpg',
#  '79387-two-modern-horsewomen.jpg',
#  '84533-dnieprostroy.jpg',
#  '175999-untitled-495.jpg',
#  '84561-evening-at-the-sea-1941.jpg',
#  '55803-enrico-nardi-reading-for-the-cardinal.jpg',
#  '114348-head-of-a-woman-14.jpg',
#  '81932-french-landscape-1.jpg',
#  '126371-still-life-with-author-s-sculpture-1930.jpg',
#  '121675-paul-henry-the-bog-cutting-sold-at-adams-on-23-october-2019-lot-30-for-80000.jpg',
#  '132383-amazon-woman-of-the-mountain-1961.jpg',
#  '118752-black-dress.jpg',
#  '70618-portrait-of-war-minister-infantry-general-and-member-of-state-council-state-aleksei-1903.jpg',
#  '136982-nude-sitting.jpg',
#  '63612-lega-gabbrigiana-in-piedi.jpg',
#  '115222-portrait-of-the-postman-joseph-roulin.jpg',
#  '80245-pegasus-1900.jpg',
#  '79492-the-unicorne-1885.jpg',
#  '104182-muriel-elsie-n-e-hirst-lady-gamage.jpg',
#  '164271-number-86a-2012.jpg',
#  '81103-clovis-1886.jpg',
#  '34955-triple-generation-1769.jpg',
#  '107955-poetul.png!Large.png',
#  '97144-landscape-with-railway-tracks.jpg',
#  '85684-karakoram.jpg',
#  '83218-the-three-stages-of-woman-sphinx-1894.jpg',
#  '66035-at-the-café.jpg',
#  '90286-the-banks-of-the-epte-at-eragny-1884.jpg',
#  '184502-landscape-cadaques-1920.jpg',
#  '175825-untitled-673.jpg',
#  '43353-flaminius-restoring-liberty-to-greece-at-the-isthmian-games.jpg',
#  '164048-61253fe89e436341a08ed70d.jpg',
#  '67532-along-the-coast(9).jpg',
#  '116792-the-cemetery-montmartre.jpg',
#  '81066-by-the-stream-autumn-1885.jpg',
#  '62226-ads-zytu.png',
#  '68914-evening-in-the-steppe.jpg',
#  '100215-the-glasgow-exhibition-1888.jpg',
#  '161415-tramonto-2001.jpg',
#  '49733-breno-porta-della-chiesa-di-sant-antonio-xilografia-di-barberis.jpg',
#  '51548-moonbeams-1.jpg',
#  '94032-the-japanis-bridge-footbridge-over-the-water-lily-pond.jpg',
#  '107334-maternity-1924.jpg',
#  '108636-champs-elysees-winter.jpg',
#  '134075-ceret-landscape-1.jpg',
#  '117706-the-laundry-boat-on-the-seine-at-herblay-1906.jpg',
#  '49568-portrait-21.jpg',
#  '129166-otto-mueller-h-user-mit-ofen-und-schwein-ca1928.jpeg!Large.jpeg',
#  '97420-portrait-of-a-woman-in-white.jpg',
#  '126072-lady-with-veil-1915.jpg',
#  '137339-bozoky-angel-x.jpg',
#  '107711-new-hope-bucks-county-1935.jpg',
#  '45393-bochmann-b0230-flottmachen-eines-fischerbootes.jpg',
#  '156620-portrait-of-a-young-david-1955.jpg',
#  '44305-arctic-whaler-homeward-bound-among-the-icebergs.jpg',
#  '124151-jacqueline-at-the-studio-1956.jpg',
#  '121220-still-life-with-a-fly-every-victuals-1932.jpg',
#  '71767-feast-of-trumpets-i-1884.jpg',
#  '104101-art-palace-reflections-1915.jpg',
#  '124586-st-denis-4.jpg',
#  '72355-portrait-of-katharine-rice-1900(1).jpg',
#  '38799-man-on-the-street.jpg',
#  '73422-karer-see-1914.jpg',
#  '92969-ships-in-harbor.jpg',
#  '84632-winger-dance-1903.jpg',
#  '35603-the-harlot-and-the-giant.jpg',
#  '126289-young-breton-1931.jpg',
#  '74374-the-first-green-may-1888.jpg',
#  '46950-don-quixote-129.jpg',
#  '67676-inconsolable-grief-1884.jpg',
#  '73810-the-bluecoat-boy-1905.jpg',
#  '175887-untitled-609.jpg',
#  '108051-chibi-i-n-ci-migiu.jpg',
#  '106787-transvaal-evening-nelspruit.jpg',
#  '70007-drawing-the-seine-1882.jpg',
#  '96997-cottages-by-a-river.jpg',
#  '175160-flower-3.jpg',
#  '30977-helvedesfossen.jpg',
#  '185320-filius-prodigus-1964.jpg',
#  '32123-honor-charles-baston-de-lariboisi-re-1815.jpg',
#  '100373-potthast-walking-in-the-hills.jpg',
#  '74555-range-of-mountains-mont-blanc-1897.jpg',
#  '79719-the-moorish-cavaliers.jpg',
#  '161233-accent-on-rhythm-anchorage-1967.jpg',
#  '126264-reclining-nude-in-the-leaves-1918(1).jpg',
#  '164236-sb-3-2009.jpg',
#  '63684-jules-breton-r-union-de-famille-bourron-marlotte-th-odore-de-banville-dans-la-for-t-de-fontainebleau.jpg',
#  '35166-sketch-for-truth-rescued-by-time-witnessed-by-history-1800.jpg',
#  '115243-crab-on-it-s-back-1889(1).jpg',
#  '52317-wagons-1921.jpg',
#  '172971-portrait-of-myself-1923.jpg',
#  '38046-hal-any-a-adam-1812.jpg',
#  '75556-peasant-woman-with-white-headscarf-1930.jpg',
#  '79710-petrarch-by-the-fountain-of-vaucluse.jpg',
#  '98433-theodore-robinson-giverny-google-art-project.jpg',
#  '112970-self-portrait-with-palette.jpg',
#  '77570-somewhere-in-america-1934.jpg',
#  '34513-horse-devoured-by-a-lion.jpg',
#  '134821-doca-do-peixe-1933.jpg',
#  '182882-reptiles-colour.jpg',
#  '135721-the-road-to-garni-1965.jpg',
#  '48918-ellen-bennett-1900.jpg',
#  '32471-portrait-of-lord-grantham-jean-auguste-dominique-ingres.jpg',
#  '62986-woman-reading-by-eastman-johnson-san-diego-museum-of-art.jpg',
#  '94936-portrait-of-a-young-woman-1887.jpg',
#  '133971-self-portrait.jpg',
#  '187412-l-alphabet-5-gimel.jpg',
#  '122801-table.jpg',
#  '99085-hugo-m-hlig-sp-tsommer.jpg',
#  '153340-the-signal-1915.jpg',
#  '85897-saint-sophia-the-almighty-wisdom-1932.jpg',
#  '126201-roses-1939.jpg',
#  '60379-windmill-on-the-cote-de-picardie-near-versailles.jpg',
#  '153237-composici-n-1917-1918-1.jpg',
#  '33220-markgr-fin-sophie-von-baden-1830.jpg',
#  '128856-mt-chocorua-no-1-1926.jpg',
#  '101169-paris-at-twilight.jpg',
#  '113728-valley-of-great-tarpatak-in-the-high-tatras-1905.jpg',
#  '93411-cliffs-of-les-petites-dalles-2.jpg',
#  '36914-hill-town-on-the-edge-of-the-campagna.jpg',
#  '89997-chestnut-orchard-in-winter-1872.jpg',
#  '108102-self-portrait.jpg',
#  '95805-three-pomegranates-and-two-apples.jpg',
#  '85763-ladakh-4.jpg',
#  '119992-farmyard-1901.jpg',
#  '79136-the-upper-rhine-1855.jpg',
#  '55510-eug-ne-alexis-girardet-dans-les-hauts-plateaux-apr-s-l-orage.jpg',
#  '81737-death-of-ellenai-1883.jpg',
#  '107311-painter-jan-bakker-at-work.jpg',
#  '51328-o-mistress-mine-where-are-you-roaming.jpg',
#  '37863-misses-mary-and-emily-mceuen-1823.jpg',
#  '51181-on-deeside-1874.jpg',
#  '115656-young-girl-standing-against-a-background-of-wheat-1890.jpg',
#  '104364-on-the-river-s-edge-1910.jpg',
#  '162106-untitled-four-figures-1951.jpg',
#  '51244-viking-norbury.jpg',
#  '170101-a-red-pennant-1936.jpg',
#  '66525-telemaco-signorini-sobborgo-di-porta-adriana-a-ravenna-1875-02.jpg',
#  '45596-carnival-in-rome-1860.jpg',
#  '152765-smoke-1912.jpg',
#  '31940-tiroler-landsturm-1809.jpg',
#  '153158-tails-of-comets.jpg',
#  '44212-spring-day-on-the-hudson.jpg',
#  '123217-blue-nude-c-1902-u-l-e77lc0.jpg',
#  '72400-martha-the-mayoress-destruction-of-novgorod-by-ivan-iii-1889.jpg',
#  '122991-dulber-sanatorium-krasnye-zori.jpg',
#  '83842-portrait-of-artist-s-mather.jpg',
#  '66778-truth-1891.jpg',
#  '64688-the-monk-at-prayer-1865.jpg',
#  '112896-trees-and-houses-1886.jpg',
#  '74338-portrait-of-writer-anton-chekhov-1886.jpg',
#  '139317-h-a-brendekilde-dansk-landsbygade-ca-1880.jpg',
#  '81254-yellow-haystacks-golden-harvest-1889.jpg',
#  '43161-reval-tallinn-ivan-konstantinovich-aivazovsky.jpg',
#  '42981-the-tempest-1886-1.jpg',
#  '92906-argenteuil-late-afternoon(1).jpg',
#  '71696-portrait-of-anna-h-leonowens-detail-1905.jpg',
#  '169655-illustration-to-a-week-of-kindness-1934-132.jpg',
#  '139065-2-vasiliy-ryabchenko-self-portrait-oil-on-canvas-1984.jpg',
#  '30282-reverend-basil-bury-beridge.jpg',
#  '96645-françoise-in-green-sewing-1909.jpg',
#  '94479-young-boy-with-a-cat-1869.jpg',
#  '185240-the-vase-of-cornflowers.jpg',
#  '47240-the-giants-nimrod.jpg',
#  '135002-parisians-1951.jpg',
#  '84432-games-in-the-sand-also-known-as-beach-with-fighters.jpg',
#  '121564-katya-with-a-dog.jpg',
#  '112373-la-modiste-1901.jpg',
#  '120093-still-life-with-pink-and-red-roses-in-a-chinese-vase-1923.jpg',
#  '73322-woman-reading-in-a-cashmere-shawl-1909.jpg',
#  '134506-the-chadoufs.jpg',
#  '202148-big95-manouch-31-jpg-1.jpg',
#  '34361-portrait-of-tien-po-1931.jpg',
#  '64010-ruins-of-the-gallien-palace.jpg',
#  '140654-the-hibiscus.jpg',
#  '82181-shadows-of-the-lagoons-and-naiades-1905.jpg',
#  '67750-portrait-of-gustave-dor-1877.jpg',
#  '61918-the-hamlet-of-optevoz-in-the-morning.jpg',
#  '126338-not-identified-1.jpg',
#  '105183-landscape-of-corsica-1.jpg',
#  '66444-three-dancers-in-yellow-skirts.jpg',
#  '64558-le-vieux-schnapseur-un-jules-avec-verre-de-schnaps-1900.jpg',
#  '49181-4.Jpeg',
#  '98715-twachtman-s-home-avondale-ohio.jpg',
#  '155167-portrait-of-the-artist-s-mother-1911.jpg',
#  '102328-in-a-room-1886.jpg',
#  '48426-under-the-trees-1865.jpg',
#  '153226-still-life-with-red-lamp-1916-18.jpg',
#  '133433-elsa-schiaparelli-gown-in-harper-s-bazaar-1937.jpg',
#  '133079-josef-apek-v-za-s-kv-tinami-1914.jpg',
#  '185601-ole.jpg',
#  '51084-the-easy-chair.jpg',
#  '106956-winter-woodland-at-breccles.jpg',
#  '90027-the-seine-at-port-marly-1872.jpg',
#  '129758-landschaft-mit-haus-in-oberau-1908(1).jpg',
#  '70516-follow-me-satan-1891.jpg',
#  '157321-eternal-mother.jpg',
#  '71835-evening-1871.jpg',
#  '121816-gorbatov-1929-venise.jpg',
#  '62638-august-pettenkoffen-szolnok-vid-ki-paraszt.jpg',
#  '34184-mischief-and-repose-1895.jpg',
#  '184268-christ-seated-christ-in-glory-1956.jpg',
#  '184302-road-to-porthclais-with-setting-sun-1975.jpg',
#  '186671-creation-of-the-world-or-microcosm.jpg',
#  '77617-2037.jpg',
#  '65681-the-conversation-at-the-round-table-1866.jpg',
#  '182755-weather-vane.jpg',
#  '184286-walter-hussey-1965.jpg',
#  '93357-boats-on-the-beach-at-etretat.jpg',
#  '186829-portrait-astrologique-1934.jpg',
#  '70408-portrait-of-the-composer-modest-musorgsky-1881.jpg',
#  '85639-lake-dal-1925.jpg',
#  '182144-composition-1929.jpg',
#  '122378-charles-portal-1st-viscount-portal-1943.jpg',
#  '186838-heads-1939.jpg',
#  '66253-four-jockeys.jpg',
#  '33222-portrait-of-hrh-princess-marie-clementine-of-orleans-1832.jpg',
#  '51349-la-salle-christening-the-country-louisiana.jpg',
#  '183443-jind-ich-tyrsk-country-cemetery.jpg',
#  '121437-still-life-red-tray-and-ash-1947.jpg',
#  '207758-the-amazon-unconscious.jpg',
#  '248836-ilbambolo.jpg',
#  '87007-watering-ligachevo-1916.jpg',
#  '184987-the-golden-age-family-of-marsupial-centaurs-1941.jpg',
#  '123653-guitar-on-pedestal-1920.jpg',
#  '84277-moonlight-1932.jpg',
#  '67170-at-the-louvre-1.jpg',
#  '75582-yd-z-koszem-yd-tragarz-1887.jpg',
#  '124005-woman-s-head-1939.jpg',
#  '184875-geological-justice.jpg',
#  '113702-sunset-over-the-bay-of-naples-1901.jpg',
#  '115776-franklin-park-boston-1895.jpg',
#  '43762-portrait-of-a-woman.jpg',
#  '71526-last-in-market-1885.jpg',
#  '121956-girl-with-bare-shoulders-1909.jpg',
#  '41822-part-of-the-saltwater-lagoon-and-view-of-mount-macedon-with-the-flemington-hills-near-melbourne-1858.jpg',
#  '60324-the-forest-of-fontainebleau.jpg',
#  '94289-getting-out-of-bed-1886.jpg',
#  '50952-just-from-town-1889.jpg',
#  '52483-roman-landscape-by-fujishima-takeji-shinshu-university.jpg',
#  '130736-ballerina-1930.jpg',
#  '120006-rocks-at-barra-1903.jpg',
#  '74064-mrs-symons-1888.jpg',
#  '31981-portrait-of-a-lady-marie-guillemine-benoist.jpg',
#  '128535-the-prisoners-1908.jpg',
#  '103445-beach-of-biarritz.jpg',
#  '66389-ballerinas-adjusting-their-dresses.jpg',
#  '93033-coal-dockers.jpg',
#  '32047-11719-p0001238-001.jpg',
#  '190374-truancy-at-the-pond.jpg',
#  '49480-olenka-and-kolya-on-the-steps.jpg',
#  '182715-emblemata-toadstool.jpg',
#  '67562-portrait-of-a-woman-1867.jpg',
#  '123673-seated-woman-olga-1920-1.jpg',
#  '118365-the-pony-1913.jpg',
#  '76509-troyekurov-in-the-kennels-1919.jpg',
#  '167686-venere-anadiomene-ii-1944.jpg',
#  '40479-paris-quai-du-louvre-1828.jpg',
#  '106575-interior-din-atelierul-din-place-dauphine-1934.jpg',
#  '95084-view-of-antibes-1893.jpg',
#  '187379-figure-with-a-dog-1964.jpg',
#  '187430-dois-lim-es-em-f-rias-1983.jpg',
#  '124330-feti-n-foi-or-1920.jpg',
#  '156361-portrait-of-an-geologist-nagy-s-rpataky-mikl-s.jpeg!Large.jpeg',
#  '159645-spring-landscape-14.jpg',
#  '95422-graziella-1910.jpg',
#  '98986-cae-19-abbema111a.jpg',
#  '80381-the-birth-of-venus.jpg',
#  '187822-harlequin-1985.jpg',
#  '94578-the-bridge-at-chatou.jpg',
#  '98997-cae-19-abbema041.jpg',
#  '47036-idylls-of-the-king-10.jpg',
#  '121473-lilac-1951.jpg',
#  '42733-seascape-1856.jpg',
#  '204749-whirl-nr-g-609-2007(1).jpg',
#  '73674-portrait-of-a-woman.jpg',
#  '67347-the-seven-trumpets-of-jericho.jpg',
#  '75208-watermill-in-finland-1902.jpg',
#  '168178-plastic-synthesis-seated-person-1915.jpg',
#  '34447-zebra-1763.jpg',
#  '98805-the-artist-s-house-through-the-trees-also-known-as-autumn-afternoon.jpg',
#  '67097-a-dandy-1873.jpg',
#  '139390-h-a-brendekilde-ved-vintertid-udateret-20-loeb-danish-art-collection.jpg',
#  '40929-kaulbach-reineke-004.jpg',
#  '51150-the-child-bride-1883.jpg',
#  '121297-the-construction-of-bathhouse-1935.jpg',
#  '176308-untitled-176.jpg',
#  '40428-theodor-leopold-weller-italienisches-m-dchen-mit-wasserkrug-555-staatliche-kunsthalle-karlsruhe.jpg',
#  '126503-portrait-of-a-young-malay-girl-1939.jpg',
#  '106731-ernest-lawson-ice-in-the-river-google-art-project.jpg',
#  '42924-yalta-1878.jpg',
#  '199393-untitled-3.jpg',
#  '116589-woman-sitting-in-a-port-1.jpg',
#  '126090-winter-landscape-1927.jpg',
#  '97249-interior-woman-reading-1880.jpg',
#  '137643-head-on-a-green-sofa-1961.jpg',
#  '74157-a-girl-from-mora.jpg',
#  '86779-city-towers-1906.jpg',
#  '43771-de-vito-m-95379-master.jpg',
#  '45014-hans-gude-seilb-ter-p-fjorden-1880.jpg',
#  '45358-wilhelm-oswald-gustav-achenbach-abendstimmung-in-der-campagna.jpg',
#  '52966-launcelot-and-guenevere.jpg',
#  '101559-the-bather-1915.jpg',
#  '115102-self-portrait-dedicated-to-paul-gauguin-1888.jpg',
#  '38826-colin-alexander-painter.jpg',
#  '107917-uli-iarna-1934.jpg',
#  '92392-a-february-morning-at-moret-sur-loing-1881.jpg',
#  '72265-41-2125933-peter-severin-kroyer-josias-comte-de-rantzau-marechal-de-france-on-horseback.jpg',
#  '73277-reclining-figure.jpg',
#  '220353-untitled.jpg']

# %% [markdown]
# # Images importing and resizing

# %%
def load_and_resize_images(image_dir, list_images):
    """
    Charge toutes les images d'un dossier, les redimensionne en conservant le ratio
    avec padding noir et les retourne sous forme de tableau NumPy.
    
    Args:
        image_dir (str): Chemin vers le dossier contenant les images.
        target_size (tuple): Taille finale des images (largeur, hauteur).
        
    Returns:
        np.ndarray: Tableau de forme (n_images, hauteur, largeur, canaux)
    """
    images_list = []
    images_names = []
    
    for filename in list_images:
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
            images_names.append(filename)
            img_path = os.path.join(image_dir, filename)
            img = Image.open(img_path).convert('RGB') 

            img_resized = img.resize((128, 128), Image.BICUBIC)
            
            # convert into an array and add to list 
            img_array = np.array(img_resized)
            images_list.append(img_array)
    
    # Convertir la liste en tableau NumPy
    images_np = np.stack(images_list)
    return images_np, images_names

# %%
image_dir = "../raw_data/sample1000"
images_np, images_names = load_and_resize_images(image_dir, list_images)

# %% [markdown]
# Test on images :

# %%
plt.imshow(images_np[0])

# %%
len(images_names)
# Out:
# 1000

# %% [markdown]
# # Define X and Y

# %%
X =  np.array(images_np, dtype='float32') / 255.0

# %%
y = df['style']

# %% [markdown]
# # Train/test split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,      
    random_state=42,
    stratify=y
)

# %%
### Normalizing pixels' intensities
X_train = X_train / 255.
X_test = X_test / 255.

# %%
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# %%
### Encoding the labels
y_train_cat = to_categorical(y_train_encoded, 10).astype('float32')
y_test_cat = to_categorical(y_test_encoded, 10).astype('float32')

# %% [markdown]
# # Initialize a model1

# %%
def initialize_model(nb_styles):
    '''instanciate and return the CNN architecture of your choice with less than 150,000 params'''
    model = Sequential()
    model.add(Input(shape=(128, 128, 3)))

    model.add(layers.Conv2D(32, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())  # normalisation pour stabiliser l'apprentissage
    model.add(layers.MaxPooling2D((2,2)))
    model.add(layers.Dropout(0.25)) 

     # Bloc 2
    model.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2,2)))
    model.add(layers.Dropout(0.25))

     # Bloc 3
    model.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2,2)))
    model.add(layers.Dropout(0.25))
    
    model.add(layers.Flatten())  
    model.add(layers.Dense(256, activation='relu')) 
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))

    ### Last layer - Classification Layer with 10 outputs corresponding to 10 digits
    model.add(layers.Dense(nb_styles, activation='softmax'))

    return model

# %%
def compile_model(model):
    '''return a compiled model suited for the CIFAR-10 task'''
    model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
    return model

# %%
model = compile_model(initialize_model(nb_styles))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │     8,388,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,486,602 (32.37 MB)
#  Trainable params: 8,485,642 (32.37 MB)
#  Non-trainable params: 960 (3.75 KB)

# %% [markdown]
# # Train the model1

# %%
def plot_history(history, title='', axs=None, exp_name=""):
    if axs is not None:
        ax1, ax2 = axs
    else:
        f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    if len(exp_name) > 0 and exp_name[0] != '_':
        exp_name = '_' + exp_name
    ax1.plot(history.history['loss'], label = 'train' + exp_name)
    ax1.plot(history.history['val_loss'], label = 'val' + exp_name)
    ax1.set_ylim(0., 2.2)
    ax1.set_title('loss')
    ax1.legend()

    ax2.plot(history.history['accuracy'], label='train accuracy'  + exp_name)
    ax2.plot(history.history['val_accuracy'], label='val accuracy'  + exp_name)
    ax2.set_ylim(0.25, 1.)
    ax2.set_title('Accuracy')
    ax2.legend()
    return (ax1, ax2)

# %%
es = EarlyStopping(patience = 3)
history = model.fit(X_train, y_train_cat, epochs=25, callbacks = [es], validation_split = 0.2, batch_size=32)
# Out:
# Epoch 1/25
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1482 - loss: 3.1822 - val_accuracy: 0.2071 - val_loss: 2.8728
# Epoch 2/25
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 16s 882ms/step - accuracy: 0.2500 - loss: 2.7074 - val_accuracy: 0.2071 - val_loss: 3.4296
# Epoch 3/25
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 17s 917ms/step - accuracy: 0.3089 - loss: 2.3883 - val_accuracy: 0.1071 - val_loss: 3.0605
# Epoch 4/25
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 842ms/step - accuracy: 0.3196 - loss: 2.2104 - val_accuracy: 0.0714 - val_loss: 2.7964
# Epoch 5/25
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 804ms/step - accuracy: 0.4054 - loss: 1.9017 - val_accuracy: 0.0714 - val_loss: 2.9679
# Epoch 6/25
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 801ms/step - accuracy: 0.4482 - loss: 1.7197 - val_accuracy: 0.2071 - val_loss: 3.4641
# Epoch 7/25
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 16s 883ms/step - accuracy: 0.5196 - loss: 1.5150 - val_accuracy: 0.1643 - val_loss: 4.7643

# %%
plot_history(history)
# Out:
# (<Axes: title={'center': 'loss'}>, <Axes: title={'center': 'Accuracy'}>)
